# %%
# !pip install openai
# !openai migrate
# Out:
# Collecting openai
#   Downloading openai-1.43.1-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai) (1.7.0)
# Collecting httpx<1,>=0.23.0 (from openai)
#   Downloading httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting jiter<1,>=0.4.0 (from openai)
#   Downloading jiter-0.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai) (2.8.2)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.5)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.10/dist-packages (from openai) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.8)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2024.8.30)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai)
#   Downloading httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (2.20.1)
# Downloading openai-1.43.1-py3-none-any.whl (365 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 365.7/365.7 kB 7.0 MB/s eta 0:00:00
# Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 3.8 MB/s eta 0:00:00
# Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 4.4 MB/s eta 0:00:00
# Downloading jiter-0.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (318 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.9/318.9 kB 8.6 MB/s eta 0:00:00
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 2.2 MB/s eta 0:00:00
# Installing collected packages: jiter, h11, httpcore, httpx, openai
# Successfully installed h11-0.14.0 httpcore-1.0.5 httpx-0.27.2 jiter-0.5.0 openai-1.43.1
# Downloading Grit CLI from https://github.com/getgrit/gritql/releases/latest/download/marzano-x86_64-unknown-linux-gnu.tar.gz
#
#
#
# Analyzing Finding files
# Processed 0 files and found 0 matches

# %%
from openai import OpenAI
from IPython.display import Image, display, HTML

from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
from email.mime.image import MIMEImage
import smtplib
import requests
from io import BytesIO
import os

client = OpenAI(
  api_key= '여기에 OpenAI API 키를 입력해주세요.',
)

client

# %%
# ChatGPT를 사용해 이메일 텍스트 생성
def generate_email_text(prompt):
    response = client.chat.completions.create(
        model="gpt-3.5-turbo",
        messages=[{
            "role": "user",
            "content": prompt
            }]
    )
    return response

email_obj = generate_email_text("유럽 투어 패키지 여름 프로모션 세일 홍보 이메일을 작성해줘")
email_txt = email_obj.choices[0].message.content

# 생성된 텍스트와 이미지 URL 출력
print(email_txt)
# Out:
# 제목: 유럽 여행 패키지, 여름 세일 이벤트!
#
# 안녕하세요,
#
# 여름이 다가오고 있습니다! 이번 여름, 특별한 유럽 여행을 계획해보세요. 저희는 특별한 투어 패키지로 여러분을 초대합니다.
#
# 이번 여름, 저희와 함께하는 유럽 투어 패키지를 특별가로 만나보세요. 유럽 전역의 아름다운 도시와 자연 경치를 즐기며 삶의 특별한 순간을 만들어보세요.
#
# 특별한 여행 프로모션을 통해 더 많은 혜택을 누리실 수 있습니다. 호텔 숙박, 관광 명소 입장료, 현지 가이드 서비스 등 모든 것이 포함된 패키지로 여행의 편의를 누리실 수 있습니다.
#
# 지금 예약하시면 최대 30% 할인 혜택도 즐기실 수 있습니다. 오직 여름에만 제공되는 특별한 혜택을 놓치지 마세요!
#
# 자세한 내용과 예약은 저희 홈페이지를 방문해주세요. 지금 바로 예약해 여름을 특별하고 잊지 못할 추억으로 만들어보세요!
#
# 감사합니다.
#
# (회사명) 투어사 부서 드림.

# %%
splited = email_txt.split('\n')

email_title = splited[0].split('제목: ')[1]
email_body = '<br/>'.join(splited[1:])

email_title, email_body
# Out:
# ('유럽 여행 패키지, 여름 세일 이벤트!',
#  '<br/>안녕하세요,<br/><br/>여름이 다가오고 있습니다! 이번 여름, 특별한 유럽 여행을 계획해보세요. 저희는 특별한 투어 패키지로 여러분을 초대합니다.<br/><br/>이번 여름, 저희와 함께하는 유럽 투어 패키지를 특별가로 만나보세요. 유럽 전역의 아름다운 도시와 자연 경치를 즐기며 삶의 특별한 순간을 만들어보세요.<br/><br/>특별한 여행 프로모션을 통해 더 많은 혜택을 누리실 수 있습니다. 호텔 숙박, 관광 명소 입장료, 현지 가이드 서비스 등 모든 것이 포함된 패키지로 여행의 편의를 누리실 수 있습니다.<br/><br/>지금 예약하시면 최대 30% 할인 혜택도 즐기실 수 있습니다. 오직 여름에만 제공되는 특별한 혜택을 놓치지 마세요!<br/><br/>자세한 내용과 예약은 저희 홈페이지를 방문해주세요. 지금 바로 예약해 여름을 특별하고 잊지 못할 추억으로 만들어보세요!<br/><br/>감사합니다.<br/><br/>(회사명) 투어사 부서 드림.')

# %%
# DALL·E를 사용해 이미지 생성
def generate_email_image(prompt):
    response = client.images.generate(
        model="dall-e-3",
        prompt=prompt,
        n=1,
        size="1024x1024"  # 이미지 크기 설정
    )
    return response

image_obj = generate_email_image('''
유럽 투어 패키지 상품 홍보를 위한 홍보 이미지를 만들어줘.
북유럽의 대표 관광지 사진들이 함께 어우러져 있고, 행복한 웃음을 띈 배낭을 멘 작은 크기의 젊은 남녀가 관광지들을 바라보고 있어.
관광지들의 사진을 더 비중있게 보여줘. 일러스트 느낌이 나게 만들어줘
''')
image_url = image_obj.data[0].url

print("\n생성된 이미지:\n")
display(Image(url=image_url))
# Out:
# 생성된 이미지:
# <img src="https://oaidalleapiprodscus.blob.core.windows.net/private/org-hQO4blUwssZE0zuGIVEgKWAJ/user-vOxcRBfFcLRpFIvSKC0trnBj/img-qq03PfxxaCBgXWXf3Wtuy8mK.png?st=2024-09-06T02%3A52%3A45Z&se=2024-09-06T04%3A52%3A45Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=d505667d-d6c1-4a0a-bac7-5c84a87759f8&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-09-05T21%3A26%3A10Z&ske=2024-09-06T21%3A26%3A10Z&sks=b&skv=2024-08-04&sig=FW%2B88zq5cs79/0%2BGlS11lJHLG5MzFBD/81NOper2tDs%3D"/>

# %%
email_text = f'''
<table align="center" border="0" cellpadding="0" cellspacing="0" width="100%" style="text-align: center; font-family: Arial, sans-serif;">
    <tr>
        <td>
            <img src="{image_url}" alt="유럽 투어 홍보 이미지" style="width: 50%; height: auto;"/>
        </td>
    </tr>
    <tr>
        <td>
            <a href="https://google.com" target="_blank" style="text-decoration: none;">
                <button style="
                    width: 40%;
                    padding: 10px 20px;
                    font-size: 24px;
                    cursor: pointer;
                    background-color: #4CAF50;
                    color: white;
                    border: none;
                    border-radius: 5px;
                    margin-top: 20px;">
                    지금 예약하기
                </button>
            </a>
        </td>
    </tr>
    <tr>
        <td style="padding-top: 20px; font-size: 18px; text-align: left;">
            {email_body}
        </td>
    </tr>
</table>
'''

# HTML을 출력하여 이미지와 버튼, 텍스트 표시
display(HTML(email_text))
# Out:
# <table align="center" border="0" cellpadding="0" cellspacing="0" width="100%" style="text-align: center; font-family: Arial, sans-serif;">
#     <tr>
#         <td>
#             <img src="https://oaidalleapiprodscus.blob.core.windows.net/private/org-hQO4blUwssZE0zuGIVEgKWAJ/user-vOxcRBfFcLRpFIvSKC0trnBj/img-qq03PfxxaCBgXWXf3Wtuy8mK.png?st=2024-09-06T02%3A52%3A45Z&se=2024-09-06T04%3A52%3A45Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=d505667d-d6c1-4a0a-bac7-5c84a87759f8&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-09-05T21%3A26%3A10Z&ske=2024-09-06T21%3A26%3A10Z&sks=b&skv=2024-08-04&sig=FW%2B88zq5cs79/0%2BGlS11lJHLG5MzFBD/81NOper2tDs%3D" alt="유럽 투어 홍보 이미지" style="width: 50%; height: auto;"/>
#         </td>
#     </tr>
#     <tr>
#         <td>
#             <a href="https://google.com" target="_blank" style="text-decoration: none;">
#                 <button style="
#                     width: 40%;
#                     padding: 10px 20px;
#                     font-size: 24px;
#                     cursor: pointer;
#                     background-color: #4CAF50;
#                     color: white;
#                     border: none;
#                     border-radius: 5px;
#                     margin-top: 20px;">
#                     지금 예약하기
#                 </button>
#             </a>
#         </td>
#     </tr>
#     <tr>
#         <td style="padding-top: 20px; font-size: 18px; text-align: left;">
#             <br/>안녕하세요,<br/><br/>여름이 다가오고 있습니다! 이번 여름, 특별한 유럽 여행을 계획해보세요. 저희는 특별한 투어 패키지로 여러분을 초대합니다.<br/><br/>이번 여름, 저희와 함께하는 유럽 투어 패키지를 특별가로 만나보세요. 유럽 전역의 아름다운 도시와 자연 경치를 즐기며 삶의 특별한 순간을 만들어보세요.<br/><br/>특별한 여행 프로모션을 통해 더 많은 혜택을 누리실 수 있습니다. 호텔 숙박, 관광 명소 입장료, 현지 가이드 서비스 등 모든 것이 포함된 패키지로 여행의 편의를 누리실 수 있습니다.<br/><br/>지금 예약하시면 최대 30% 할인 혜택도 즐기실 수 있습니다. 오직 여름에만 제공되는 특별한 혜택을 놓치지 마세요!<br/><br/>자세한 내용과 예약은 저희 홈페이지를 방문해주세요. 지금 바로 예약해 여름을 특별하고 잊지 못할 추억으로 만들어보세요!<br/><br/>감사합니다.<br/><br/>(회사명) 투어사 부서 드림.
#         </td>
#     </tr>
# </table>

# %%
# 이메일 정보 설정
# 만약 구글 smtp를 사용하고 싶다면, 본인 계정 설정으로 들어가서
# 2단계 인증을 설정한 후, 상단 검색창에 '앱비밀번호' 검색 및 메뉴에 들어가
# 앱 비밀번호를 확인한 후 아래 password 변수에 넣어야 한다(계정의 비번과 별개)
subject = email_title
sender = "nababora77@gmail.com"
recipient = "nababora77@gmail.com"
SMTP_SERVER = "smtp.gmail.com"
smtp_port = 587
username = "nababora77@gmail.com"
password = "put password here"

# %%
msg = MIMEMultipart("alternative")
msg["From"] = sender
msg["To"] = recipient
msg["Subject"] = subject

# HTML 본문 추가
msg.attach(MIMEText(email_text, "html"))

# 이메일 전송
try:
    server = smtplib.SMTP(SMTP_SERVER, smtp_port)
    server.starttls()  # TLS 시작
    server.login(username, password)
    server.sendmail(sender, recipient, msg.as_string())
    server.quit()
    print("이메일 전송 성공")
except Exception as e:
    print(f"이메일 전송 실패: {e}")
# Out:
# 이메일 전송 성공

# %%
# 구글 드라이브 연결

from google.colab import drive
import os

drive.mount('/content/drive')

project_path = '/content/drive/MyDrive/ch6'
os.makedirs(project_path, exist_ok=True)

# 현재 경로를 /content/drive로 설정
os.chdir(project_path)
print("현재 작업 디렉토리:", os.getcwd())
# Out:
# Mounted at /content/drive
# 현재 작업 디렉토리: /content/drive/MyDrive/ch6

# %%
# gcc 컴파일러 설치
# !apt-get update && apt-get install -y gcc
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Ign:3 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 https://r2u.stat.illinois.edu/ubuntu jammy Release [5,713 B]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:7 https://r2u.stat.illinois.edu/ubuntu jammy Release.gpg [793 B]
# Get:8 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:10 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,590 kB]
# Hit:11 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:12 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:13 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:14 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [8,371 kB]
# Get:15 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,159 kB]
# Get:16 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [2,318 kB]
# Fetched 14.8 MB in 2s (6,611 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# gcc is already the newest version (4:11.2.0-1ubuntu1).
# gcc set to manually installed.
# 0 upgraded, 0 newly installed, 0 to remove and 54 not upgraded.

# %%
# 소스코드 출력
with open("bof_debug.c", "r") as f:
    code = f.read()

print(code)
# Out:
# #include <stdio.h>
# #include <string.h>
# #include <stdlib.h>
#
# #define BUFFER_SIZE 32  // 버퍼 크기 정의
#
# // 조건 검사를 위한 함수 선언
# int is_length_valid(const char *input);
# int is_first_char_valid(const char *input);
# int is_middle_char_valid(const char *input);
# int is_sum_valid(const char *input);
# int is_key_match(const char *input);
# void vulnerable_function(const char *input);
#
# // 각 조건별 검사를 위한 함수들
#
# // 입력 문자열의 길이가 유효한지 확인
# int is_length_valid(const char *input) {
#     int len = strlen(input);
#     if (len > 16) {
#         printf("Condition 1 passed: Length is greater than 16.\n");
#         return 1;
#     }
#     printf("Condition 1 failed: Length is not greater than 16.\n");
#     return 0;
# }
#
# // 입력 문자열의 첫 번째 문자가 'A'인지 확인
# int is_first_char_valid(const char *input) {
#     if (input[0] == 'A') {
#         printf("Condition 2 passed: First character is 'A'.\n");
#         return 1;
#     }
#     printf("Condition 2 failed: First character is not 'A'.\n");
#     return 0;
# }
#
# // 입력 문자열의 길이가 짝수이고, 중간 값이 'Z'인지 확인
# int is_middle_char_valid(const char *input) {
#     int len = strlen(input);
#     if (len % 2 == 0 && input[len / 2 - 1] == 'Z') {
#         printf("Condition 3 passed: Middle character is 'Z' and length is even.\n");
#         return 1;
#     }
#     printf("Condition 3 failed: Middle character is not 'Z' or length is not even.\n");
#     return 0;
# }
#
# // 마지막 세 문자의 ASCII 값 합이 300인지 확인
# int is_sum_valid(const char *input) {
#     int len = strlen(input);
#     if (len < 3) {
#         printf("Condition 4 failed: Length is less than 3, cannot check sum.\n");
#         return 0;
#     }
#
#     int sum = input[len - 1] + input[len - 2] + input[len - 3];
#     if (sum == 300) {
#         printf("Condition 4 passed: Sum of last three characters is 300.\n");
#         return 1;
#     }
#     printf("Condition 4 failed: Sum of last three characters is not 300 (%d).\n", sum);
#     return 0;
# }
#
# // 입력 문자열이 특정 "비밀 키"를 포함하는지 확인
# int is_key_match(const char *input) {
#     if (strstr(input, "secret123") != NULL) {
#         printf("Condition 5 passed: Input contains 'secret123'.\n");
#         return 1;
#     }
#     printf("Condition 5 failed: Input does not contain 'secret123'.\n");
#     return 0;
# }
#
# // 취약한 함수: 입력 문자열을 고정된 크기의 버퍼에 복사
# void vulnerable_function(const char *input) {
#     char buffer[BUFFER_SIZE];
#
#     // 조건이 모두 만족되면 오버플로우를 유발하도록 input을 버퍼에 복사
#     int cond1 = is_length_valid(input);
#     int cond2 = is_first_char_valid(input);
#     int cond3 = is_middle_char_valid(input);
#     int cond4 = is_sum_valid(input);
#     int cond5 = is_key_match(input);
#
#     if (cond1 && cond2 && cond3 && cond4 && cond5) {
#         // 입력 길이가 BUFFER_SIZE보다 클 경우, 오버플로우 발생 가능
#         printf("All conditions met! Executing vulnerable function...\n");
#         strcpy(buffer, input);  // 버퍼 오버플로우 발생 지점
#         printf("Buffer contents: %s\n", buffer);
#     } else {
#         printf("Conditions not met. Buffer overflow did not occur.\n");
#     }
# }
#
# int main() {
#     char input[100];
#
#     printf("Enter the input: ");
#     fgets(input, 100, stdin);
#
#     // Remove newline character from input
#     input[strcspn(input, "\n")] = '\0';
#
#     // 취약한 함수 호출
#     vulnerable_function(input);
#
#     return 0;
# }

# %%
# 보호 옵션을 비활성화하고 컴파일
# !gcc -fno-stack-protector -z execstack -no-pie -o bof bof.c

# %%
# !echo "AZZZZZZZZZZZZZZZZZZZZZZZZZZZZZZZsecret123ddd" | ./bof
# Out:
# Enter the input (type 'quit' to exit): All conditions met! Executing vulnerable function...
# Buffer contents: AZZZZZZZZZZZZZZZZZZZZZZZZZZZZZZZsecret123ddd
# /bin/bash: line 1:  1316 Done                    echo "AZZZZZZZZZZZZZZZZZZZZZZZZZZZZZZZsecret123ddd"
#       1317 Segmentation fault      (core dumped) | ./bof
